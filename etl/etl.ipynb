# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

# %% [markdown]
# ### Load CSV files

# %%
basedir = "../dataset/"
csv_files = ["br-capes-colsucup-discentes-2013a2016-2017-12-02_2013.csv", \
                "br-capes-colsucup-discentes-2013a2016-2017-12-02_2014.csv", \
                "br-capes-colsucup-discentes-2013a2016-2017-12-02_2015.csv", \
                "br-capes-colsucup-discentes-2013a2016-2017-12-02_2016.csv", \
                "br-capes-colsucup-discentes-2017-2018-07-10.csv"]

# %%
df = list()
for i in range(len(csv_files)):
    df.append(pd.read_csv(basedir + csv_files[i], index_col=17, sep=';',encoding='iso-8859-1'))
    print("{} read.".format(csv_files[i]))

discentes = pd.concat(df)
# Out:
# br-capes-colsucup-discentes-2013a2016-2017-12-02_2013.csv read.
# br-capes-colsucup-discentes-2013a2016-2017-12-02_2014.csv read.
# br-capes-colsucup-discentes-2013a2016-2017-12-02_2015.csv read.
# br-capes-colsucup-discentes-2013a2016-2017-12-02_2016.csv read.
# br-capes-colsucup-discentes-2017-2018-07-10.csv read.

# %%
discentes.head()
# Out:
#            AN_BASE  NM_GRANDE_AREA_CONHECIMENTO  CD_AREA_AVALIACAO  \
# ID_PESSOA
# 1236858       2013  LINGÜÍSTICA, LETRAS E ARTES                 41
# 355606        2013  LINGÜÍSTICA, LETRAS E ARTES                 41
# 850220        2013  LINGÜÍSTICA, LETRAS E ARTES                 41
# 377490        2013  LINGÜÍSTICA, LETRAS E ARTES                 41
# 1083497       2013  LINGÜÍSTICA, LETRAS E ARTES                 41
#
#               NM_AREA_AVALIACAO SG_ENTIDADE_ENSINO  \
# ID_PESSOA
# 1236858    LETRAS / LINGUÍSTICA               UNIR
# 355606     LETRAS / LINGUÍSTICA               UNIR
# 850220     LETRAS / LINGUÍSTICA               UNIR
# 377490     LETRAS / LINGUÍSTICA               UNIR
# 1083497    LETRAS / LINGUÍSTICA               UNIR
#
#                          NM_ENTIDADE_ENSINO CS_STATUS_JURIDICO  \
# ID_PESSOA
# 1236858    UNIVERSIDADE FEDERAL DE RONDÔNIA            FEDERAL
# 355606     UNIVERSIDADE FEDERAL DE RONDÔNIA            FEDERAL
# 850220     UNIVERSIDADE FEDERAL DE RONDÔNIA            FEDERAL
# 377490     UNIVERSIDADE FEDERAL DE RONDÔNIA            FEDERAL
# 1083497    UNIVERSIDADE FEDERAL DE RONDÔNIA            FEDERAL
#
#           DS_DEPENDENCIA_ADMINISTRATIVA NM_MODALIDADE_PROGRAMA  \
# ID_PESSOA
# 1236858                         PÚBLICA              ACADÊMICO
# 355606                          PÚBLICA              ACADÊMICO
# 850220                          PÚBLICA              ACADÊMICO
# 377490                          PÚBLICA              ACADÊMICO
# 1083497                         PÚBLICA              ACADÊMICO
#
#           NM_GRAU_PROGRAMA           ...             \
# ID_PESSOA                            ...
# 1236858           MESTRADO           ...
# 355606            MESTRADO           ...
# 850220            MESTRADO           ...
# 377490            MESTRADO           ...
# 1083497           MESTRADO           ...
#
#           DS_GRAU_ACADEMICO_DISCENTE ST_INGRESSANTE NM_SITUACAO_DISCENTE  \
# ID_PESSOA
# 1236858                     MESTRADO            NÃO            DESLIGADO
# 355606                      MESTRADO            NÃO             TITULADO
# 850220                      MESTRADO            NÃO          MATRICULADO
# 377490                      MESTRADO            NÃO          MATRICULADO
# 1083497                     MESTRADO            SIM          MATRICULADO
#
#           DT_MATRICULA_DISCENTE DT_SITUACAO_DISCENTE  QT_MES_TITULACAO  \
# ID_PESSOA
# 1236858      01DEC2012:00:00:00   01JAN2013:00:00:00                 0
# 355606       11MAY2010:00:00:00   22NOV2013:00:00:00                42
# 850220       01DEC2012:00:00:00   01DEC2012:00:00:00                 0
# 377490       01MAR2011:00:00:00   01MAR2011:00:00:00                 0
# 1083497      17OCT2013:00:00:00   17OCT2013:00:00:00                 0
#
#                                          NM_TESE_DISSERTACAO  NM_ORIENTADOR  \
# ID_PESSOA
# 1236858                                        NÃO SE APLICA  NÃO SE APLICA
# 355606     COMUNIDADE DE JESUS: DIALOGISMO, POLIFONIA E I...  MIGUEL NENEVE
# 850220                                         NÃO SE APLICA  NÃO SE APLICA
# 377490                                         NÃO SE APLICA  NÃO SE APLICA
# 1083497                                        NÃO SE APLICA  NÃO SE APLICA
#
#           ID_ADD_FOTO_PROGRAMA ID_ADD_FOTO_PROGRAMA_IES
# ID_PESSOA
# 1236858                  19660                    80036
# 355606                   19660                    80036
# 850220                   19660                    80036
# 377490                   19660                    80036
# 1083497                  19660                    80036
#
# [5 rows x 32 columns]

# %%
table = pa.Table.from_pandas(discentes) #, timestamps_to_ms=True)
pq.write_table(table, '../dataset/br-capes-colsucup-discentes.parquet', compression='GZIP')
