# %% [markdown]
# # Docentes por programa

# %%
# %load_ext sql

# %%
# %%sql postgresql://capesdb_user:c4pes@capesdb:5432/capesdb
#
#     SELECT
#         AN_BASE
#         ,SG_ENTIDADE_ENSINO
#         ,NM_PROGRAMA_IES
#         ,CD_CONCEITO_PROGRAMA
# FROM FATO_PROGRAMA WHERE cd_programa_ies = '15001016004P8'
# Out:
# 4 rows affected.
# [(2013, 'UFPA', 'ENGENHARIA ELÉTRICA', 5),
#  (2014, 'UFPA', 'ENGENHARIA ELÉTRICA', 5),
#  (2015, 'UFPA', 'ENGENHARIA ELÉTRICA', 5),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 5)]

# %%
# %%sql
#     SELECT
#         AN_BASE
#         ,SG_ENTIDADE_ENSINO
#         ,NM_PROGRAMA_IES
#         ,ID_PESSOA
#         ,NM_DOCENTE
#     FROM FATO_DOCENTE WHERE cd_programa_ies = '15001016004P8'
#     AND AN_BASE = 2016
# Out:
#  * postgresql://capesdb_user:***@capesdb:5432/capesdb
# 28 rows affected.
# [(2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 15002, 'JOAO CRISOSTOMO WEYL ALBUQUERQUE COSTA'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 514582, 'VICTOR DMITRIEV'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 523464, 'EVALDO GONCALVES PELAES'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 529644, 'ROBERTO CELIO LIMAO DE OLIVEIRA'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 35002, 'ALDEBARO BARRETO DA ROCHA KLAUTAU JUNIOR'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 24080, 'JOAO TAVARES PINHO'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 40444, 'MARCOS BENEDITO CALDAS COSTA'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 830512, 'CAROLINA DE MATTOS AFFONSO'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 527819, 'WALTER BARRA JUNIOR'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 536002, 'JORDAN DEL NERO'),
#  (2016, 'UFPA', 'ENGENHARIA ELÉTRICA', 397151, 'ADAMO LIMA DE SANTANA'),
# ...
