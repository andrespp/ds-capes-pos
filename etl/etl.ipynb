# %%
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd

# %% [markdown]
# ### Load CSV files

# %%
basedir = "./datasrc/"
#csv_files = ["br-capes-colsucup-discentes-2013a2016-2017-12-02_2013.csv", \
#                "br-capes-colsucup-discentes-2013a2016-2017-12-02_2014.csv", \
#                "br-capes-colsucup-discentes-2013a2016-2017-12-02_2015.csv", \
#                "br-capes-colsucup-discentes-2013a2016-2017-12-02_2016.csv", \
#                "br-capes-colsucup-discentes-2017-2018-07-10.csv"]
csv_files = ["br-capes-colsucup-docente-2017-2018-08-10.csv.gz"]

# %%
df = list()
for i in range(len(csv_files)):
    print(basedir + csv_files[i])
    df.append(pd.read_csv(basedir + csv_files[i], index_col=17, sep=';',encoding='iso-8859-1'))
    print("{} read.".format(csv_files[i]))

discentes = pd.concat(df)
# Out:
# ./datasrc/br-capes-colsucup-docente-2017-2018-08-10.csv.gz
# br-capes-colsucup-docente-2017-2018-08-10.csv.gz read.

# %%
discentes.head()
# Out:
#            AN_BASE  CD_AREA_AVALIACAO    NM_AREA_AVALIACAO  \
# ID_PESSOA
# 380391        2017                 42  CIÊNCIAS AGRÁRIAS I
# 434735        2017                 42  CIÊNCIAS AGRÁRIAS I
# 535387        2017                 42  CIÊNCIAS AGRÁRIAS I
# 536386        2017                 42  CIÊNCIAS AGRÁRIAS I
# 526121        2017                 38             EDUCAÇÃO
#
#           NM_GRANDE_AREA_CONHECIMENTO NM_AREA_CONHECIMENTO CD_PROGRAMA_IES  \
# ID_PESSOA
# 380391              CIÊNCIAS AGRÁRIAS            AGRONOMIA   42009014001P6
# 434735              CIÊNCIAS AGRÁRIAS            AGRONOMIA   42009014001P6
# 535387              CIÊNCIAS AGRÁRIAS            AGRONOMIA   42009014001P6
# 536386              CIÊNCIAS AGRÁRIAS            AGRONOMIA   42009014001P6
# 526121               CIÊNCIAS HUMANAS             EDUCAÇÃO   32006012003P1
#
#           NM_PROGRAMA_IES    NM_GRAU_PROGRAMA NM_MODALIDADE_PROGRAMA  \
# ID_PESSOA
# 380391          AGRONOMIA  MESTRADO/DOUTORADO              ACADÊMICO
# 434735          AGRONOMIA  MESTRADO/DOUTORADO              ACADÊMICO
# 535387          AGRONOMIA  MESTRADO/DOUTORADO              ACADÊMICO
# 536386          AGRONOMIA  MESTRADO/DOUTORADO              ACADÊMICO
# 526121           EDUCAÇÃO  MESTRADO/DOUTORADO              ACADÊMICO
#
#            CD_CONCEITO_PROGRAMA           ...            IN_DOUTOR  \
# ID_PESSOA                                 ...
# 380391                        4           ...                    S
# 434735                        4           ...                    S
# 535387                        4           ...                    S
# 536386                        4           ...                    S
# 526121                        5           ...                    S
#
#           AN_TITULACAO NM_GRAU_TITULACAO CD_AREA_BASICA_TITULACAO  \
# ID_PESSOA
# 380391            2015         DOUTORADO                 50500007
# 434735            2007         DOUTORADO                 50102010
# 535387            2003         DOUTORADO                 20500009
# 536386            2003         DOUTORADO                 50101005
# 526121            2003         DOUTORADO                 70800006
#
#           NM_AREA_BASICA_TITULACAO SG_IES_TITULACAO  \
# ID_PESSOA
# 380391        MEDICINA VETERINÁRIA            UFRGS
# 434735               FITOPATOLOGIA             UFLA
# 535387                    ECOLOGIA          PARIS 4
# 536386             CIÊNCIA DO SOLO             INRA
# 526121                    EDUCAÇÃO          UNICAMP
#
#                                         NM_IES_TITULACAO  \
# ID_PESSOA
# 380391         UNIVERSIDADE FEDERAL DO RIO GRANDE DO SUL
# 434735                    UNIVERSIDADE FEDERAL DE LAVRAS
# 535387              UNIVERSITÉ PARIS-SORBONNE - PARIS IV
# 536386     INSTITUT NATIONAL DE LA RECHERCHE AGRONOMIQUE
# 526121                 UNIVERSIDADE ESTADUAL DE CAMPINAS
#
#           NM_PAIS_IES_TITULACAO ID_ADD_FOTO_PROGRAMA ID_ADD_FOTO_PROGRAMA_IES
# ID_PESSOA
# 380391                   BRASIL                69993                   133706
# 434735                   BRASIL                69993                   133706
# 535387                   FRANÇA                69993                   133706
# 536386                   FRANÇA                69993                   133706
# 526121                   BRASIL                70115                   133877
#
# [5 rows x 36 columns]

# %%
table = pa.Table.from_pandas(discentes) #, timestamps_to_ms=True)
pq.write_table(table, './dataset/br-capes-colsucup-discentes.parquet', compression='GZIP')
